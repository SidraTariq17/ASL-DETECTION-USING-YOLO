# %%
import os
import glob
from IPython.display import Image, display

# %%
from IPython import display
display.clear_output()

# %%
# !nvidia-smi
# Out:
# Tue Oct 29 20:14:29 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.90.07              Driver Version: 550.90.07      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8             11W /   70W |       1MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
HOME = os.getcwd()


print(HOME)
# Out:
# /kaggle/working

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 877.7/877.7 kB 31.5 MB/s eta 0:00:00
# ...

# %%
import ultralytics


ultralytics.checks()
# Out:
# Ultralytics 8.3.24 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5933.9/8062.4 GB disk)

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow
# Out:
# /kaggle/working/datasets
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 4.7 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="hMy9moATp2etps0iwcok")
project = rf.workspace("sign-language-oyykt").project("american-sign-language-letters-gxpdm")
version = project.version(6)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to American-sign-language-letters-6 in yolov8:: 100%|██████████| 3016/3016 [00:00<00:00, 8338.41it/s]

# %%
# %cd {HOME}
# %cd {dataset.location}
# Out:
# /kaggle/working
# /kaggle/working/datasets/American-sign-language-letters-6

# %%
# %cd {HOME}
# !yolo task=detect mode=train model=/kaggle/input/bestptt/best.pt data={dataset.location}/data.yaml epochs=30 imgsz=800 --save
# Out:
# /kaggle/working
# WARNING ⚠️ argument '--save' does not require leading dashes '--', updating to 'save'.
# Ultralytics 8.3.24 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# %cd {HOME}
# !yolo task=detect mode=train model=/kaggle/input/bestptt/best.pt data={dataset.location}/data.yaml epochs=30 imgsz=800 save
# Out:
# /kaggle/working
# Ultralytics 8.3.24 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from IPython.display import FileLink

# Specify the path to your best.pt file
file_path = 'runs/detect/train2/weights/best.pt'

# Display a download link
FileLink(file_path)
# Out:
# /kaggle/working/runs/detect/train2/weights/best.pt

# %%
# !ls /kaggle/working

# %%
# %cd {HOME}
# !yolo task=detect mode=train model=/kaggle/input/besttt/best.pt data={dataset.location}/data.yaml epochs=50 imgsz=800 save
# Out:
# /kaggle/working
# Ultralytics 8.3.24 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !ls {HOME}/runs/detect/train/
# Out:
# F1_curve.png					   train_batch1.jpg
# PR_curve.png					   train_batch2.jpg
# P_curve.png					   train_batch2680.jpg
# R_curve.png					   train_batch2681.jpg
# args.yaml					   train_batch2682.jpg
# confusion_matrix.png				   val_batch0_labels.jpg
# confusion_matrix_normalized.png			   val_batch0_pred.jpg
# events.out.tfevents.1730233005.a110d68969b8.140.0  val_batch1_labels.jpg
# labels.jpg					   val_batch1_pred.jpg
# labels_correlogram.jpg				   val_batch2_labels.jpg
# results.csv					   val_batch2_pred.jpg
# results.png					   weights
# train_batch0.jpg

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=900)
# Out:
# /kaggle/working

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/results.png', width=600)
# Out:
# /kaggle/working

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=600)
# Out:
# /kaggle/working

# %%
# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Ultralytics 8.3.24 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 268 layers, 43,626,654 parameters, 0 gradients, 164.9 GFLOPs
# val: Scanning /kaggle/working/datasets/American-sign-language-letters-6/valid/la
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        285        285      0.969      0.952       0.99      0.681
#                      A         13         13      0.986          1      0.995      0.601
#                      B          8          8      0.979          1      0.995      0.741
#                      C          5          5          1      0.778      0.995      0.649
#                      D          6          6          1      0.808      0.972      0.725
#                      E          7          7          1      0.887      0.995      0.627
#                      F         10         10      0.982          1      0.995      0.727
# ...

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source={dataset.location}/test/images
# Out:
# /kaggle/working
# Ultralytics 8.3.24 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 268 layers, 43,626,654 parameters, 0 gradients, 164.9 GFLOPs
#
# image 1/146 /kaggle/working/datasets/American-sign-language-letters-6/test/images/100_jpg.rf.c78a894d50e6995e241fabcb0444e8b8.jpg: 800x800 1 V, 81.8ms
# image 2/146 /kaggle/working/datasets/American-sign-language-letters-6/test/images/104_jpg.rf.de3f6742f30511b26bd77ba363ea3d6f.jpg: 800x800 (no detections), 60.4ms
# image 3/146 /kaggle/working/datasets/American-sign-language-letters-6/test/images/10_jpg.rf.9ac608ddfbe5371bf1472090554063ea.jpg: 800x800 1 K, 61.9ms
# image 4/146 /kaggle/working/datasets/American-sign-language-letters-6/test/images/112_jpg.rf.17b23bdb144457dd105d7b6eaf376985.jpg: 800x800 1 O, 59.0ms
# image 5/146 /kaggle/working/datasets/American-sign-language-letters-6/test/images/116_jpg.rf.36d16798d9079f412d89415678300b78.jpg: 800x800 1 B, 57.8ms
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/runs/detect/predict/*.jpg')[:3]:
    display(Image(filename=image_path, width=600))
    print("\n")

# %%
from IPython.display import FileLink

# Specify the path to your best.pt file
file_path = 'runs/detect/train/weights/last.pt'

# Display a download link
FileLink(file_path)
# Out:
# /kaggle/working/runs/detect/train/weights/last.pt

# %%
import os
import glob
from IPython.display import Image, display

# %%
from IPython import display
display.clear_output()

# %%
# !nvidia-smi
# Out:
# Thu Oct 31 19:27:46 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.90.07              Driver Version: 550.90.07      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8             10W /   70W |       1MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
HOME = os.getcwd()


print(HOME)
# Out:
# /kaggle/working

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 879.0/879.0 kB 14.8 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow
# Out:
# /kaggle/working/datasets
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 2.2 MB/s eta 0:00:00
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="hMy9moATp2etps0iwcok")
project = rf.workspace("sign-language-oyykt").project("american-sign-language-letters-gxpdm")
version = project.version(6)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to American-sign-language-letters-6 in yolov8:: 100%|██████████| 3016/3016 [00:00<00:00, 8217.17it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# %cd {HOME}
# !yolo task=detect mode=train model=/kaggle/input/bestttt/best.pt data={dataset.location}/data.yaml epochs=45 imgsz=800 save
# Out:
# /kaggle/working
# Ultralytics 8.3.26 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/results.png', width=600)
# Out:
# /kaggle/working

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)
# Out:
# /kaggle/working

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=600)
# Out:
# /kaggle/working

# %%
# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Ultralytics 8.3.26 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 268 layers, 43,626,654 parameters, 0 gradients, 164.9 GFLOPs
# val: Scanning /kaggle/working/datasets/American-sign-language-letters-6/valid/la
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        285        285       0.97      0.949      0.986       0.68
#                      A         13         13      0.989          1      0.995      0.607
#                      B          8          8      0.988          1      0.995      0.742
#                      C          5          5          1      0.672      0.962      0.661
#                      D          6          6          1      0.802      0.972      0.719
#                      E          7          7      0.978          1      0.995       0.57
#                      F         10         10      0.982          1      0.995      0.739
# ...
